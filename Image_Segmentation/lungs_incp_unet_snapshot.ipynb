# %% [markdown]
# # Image Segmentation using an Inception based U-Net model with snapshots and cosine annealed learning rate.
#
# This notebook is an example notebook of using image data and its corresponding masks to produce masks for the test images whose mask are needed.
#
# Segmentation of an image is to classify each pixel of an image into 2 or more classes. For problems where only one object of interest is needed to be determined in an image containing the object and background, we need to classify every pixel into 2 classes as is the case with the dataset/ model used in this notebook.
#
# Here is a notebook to do the same using neural network model to find the masks of the images.

# %%
import keras, tensorflow, sys
keras.__version__, tensorflow.__version__, sys.version
# Out:
# Using TensorFlow backend.
# ('2.2.2',
#  '1.10.0',
#  '3.6.6 |Anaconda, Inc.| (default, Jun 28 2018, 11:27:44) [MSC v.1900 64 bit (AMD64)]')

# %% [markdown]
# Used for training on 2nd GPU in a multi-GPU environment.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

# %% [markdown]
# ## Import packages
#
# Import different packages for handling images and building the keras model.

# %%
# Packages for processing/ loading image files
from glob import glob 
import cv2
import pandas as pd
import numpy as np
import time
from sklearn.model_selection import train_test_split

# Packages for the model
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, BatchNormalization
from keras.layers import LeakyReLU, Concatenate, concatenate, UpSampling2D, Add, Input,Dense
from keras.models import Model,load_model
from keras.optimizers import Adam
import tensorflow as tf
import keras.backend as K
from keras.preprocessing.image import ImageDataGenerator

# Import the snapshot builder callback file locally which is used for dynamic LR.
from snapshot import SnapshotCallbackBuilder

# Pacakge for viewing the images
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Function to load and process Image
#
# Load image using opencv function imread(path, 1 for read as colour image).
#
# Cv2 loads the image with B channel first. We converte this to R channel first.
#
# Gaussian Blur is applied to image to have smoother transitions in image.
#
# Image is scaled to have values between 0 and 1.
#
# For processing masks it is made sure that shapes are as required and the image is thresholded to converte arbitary values to 0 or 255.

# %%
# Preprocess image for of top view training/ detection
def preprocess_img(img_file):
    im = cv2.imread(img_file, 1)
    im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
    im = cv2.GaussianBlur(im, (5,5), 0)
    im = im/255
    return im

# Preprocess masks top view
def preprocess_mask(img_file):
    im = cv2.imread(img_file, 0)
    im = im.reshape(im.shape[0], im.shape[1], 1)
    _, im = cv2.threshold(im, 200, 255, cv2.THRESH_BINARY)
    im = cv2.GaussianBlur(im,(5,5), 0)
    im = im.reshape(im.shape[0], im.shape[1], 1)
    im = im/255
    return im

# %% [markdown]
# ## Inception Block
#
# Instead of a single convolution block an inception block is used to extract the features from the image.
#
# In an inception block input is divided into multiple instances and passed to different combinations of convolution layer and then the output from all the combinations are concatenated and passed further.
#
# An inception block extracts richer feature compared to a convolution layer since in an inception block same input feature is passed through different sized kernel of convolutions, which enables the model to process the features from different point of views.
#
# Different combinations of layers can be experimented with. Also different inception blocks can be combined in a same model and used as done in the actual inception model.
#
# Link to the paper for Inception model is [here](https://arxiv.org/pdf/1602.07261.pdf).

# %%
def incp_v3(x, nb_filters):
    b_1 = Conv2D(nb_filters, (1,1), padding='same', kernel_initializer="glorot_normal")(x)
    b_1 = BatchNormalization(axis=3)(b_1)
    b_1 = LeakyReLU()(b_1)
    b_1 = Conv2D(nb_filters, (3,3), padding='same', kernel_initializer="glorot_normal")(b_1)
    b_1 = BatchNormalization(axis=3)(b_1)
    b_1 = LeakyReLU()(b_1)
    b_1 = Conv2D(nb_filters, (3,3), padding='same', kernel_initializer="glorot_normal")(b_1)
    b_1 = BatchNormalization(axis=3)(b_1)
    b_1 = LeakyReLU()(b_1)
    
    
    b_2 = Conv2D(nb_filters, (1,1), padding='same', kernel_initializer="glorot_normal")(x)
    b_2 = BatchNormalization(axis=3)(b_2)
    b_2 = LeakyReLU()(b_2)
    b_2 = Conv2D(nb_filters, (3,3), padding='same', kernel_initializer="glorot_normal")(b_2)
    b_2 = BatchNormalization(axis=3)(b_2)
    b_2 = LeakyReLU()(b_2)


    b_3 = Conv2D(nb_filters, (1,1), padding='same', kernel_initializer="glorot_normal")(x)
    b_3 = BatchNormalization(axis=3)(b_3)
    b_3 = LeakyReLU()(b_3)

    
    b_4 = MaxPooling2D((2,2), strides=(1,1), padding='same')(x)
    b_4 = Conv2D(nb_filters, (1,1), padding='same', kernel_initializer="glorot_normal")(b_4)
    b_4 = BatchNormalization(axis=3)(b_4)
    b_4 = LeakyReLU()(b_4)
    
    x = concatenate([b_1, b_2, b_3, b_4], axis=3)
    return x

# %% [markdown]
# ## Dataset
#
# The dataset for this notebook is taken from -> https://www.kaggle.com/kmader/finding-lungs-in-ct-data/home .
#
# The dataset contains 267 images of ct scans of lungs with masks representing the lung portion in each of the image.
#
# The images in the dataset are in tif format.

# %%
# Load the training files
X = []
file_train = "./finding-lungs-in-ct-data/2d_images/*.tif"
file_train = glob(file_train)
for i, file in enumerate(file_train):
        im = preprocess_img(file)
        X.append(im)
X = np.array(X)



## change new_crop_blunt_mask file to point to the file where new training masks are present.
file_mask = glob("./finding-lungs-in-ct-data/2d_masks/*.tif")
y = []
for i in file_mask:
        im = preprocess_mask(i)
        y.append(im)  
y = np.array(y)



print(len(X),len(y),len(X)==len(y))
# Out:
# 267 267 True

# %% [markdown]
# ## Sample Image and its corresponding mask

# %%
plt.imshow(X[-100][:,:,:])
plt.gray()

# %%
plt.imshow(y[-100][:,:,0])
plt.gray()

# %%
X.shape, y.shape
# Out:
# ((267, 512, 512, 3), (267, 512, 512, 1))

# %% [markdown]
# ## Auto Encoder with U-Net Architecture
#
# In an auto encoder model for an image, features are extracted and reduced using a convolution network (or another feature extractor like using inception blocks). The feature size is reduced by max pooling features from each kernel in the convolution. Since, over here, our aim is to get the mask of the input image, we reconstruct the latent features (features found after the last max pooling layer), into an image of same size (channel size may differ). This is done by upsampling (copying the same value in each of the kernel position) and convolution of these features.
#
# To increase the accuracy of the network an architecture known as U-Net was used. On the decoder side where reconstruction of image is done, along with latent features, corresponding features from encoder is concatenated in each layer. These allows the decoder network to directly look at the features of corresponding layers in the encoder, to enchance feature reproduction. The paper on [U-Net architecture](https://arxiv.org/abs/1505.04597) gives detail information on the same.

# %%
# Initalize the Inception based UNET model

inp = Input(X[0].shape)
x = incp_v3(inp, 8) 

b_0 = x

x = MaxPooling2D((2, 2), strides=2)(x) 
b_1 = (x)

x = incp_v3(x, 16) 

x = MaxPooling2D((2, 2), strides=2)(x) 
b_2 = (x) 

x = incp_v3(x, 32) 

x = MaxPooling2D((2, 2), strides=2)(x) 
b_3 =(x) 

x = incp_v3(x, 64) 

encoded = MaxPooling2D((2, 2))(x) 

x = incp_v3(encoded, 64)

x = UpSampling2D((2, 2))(x) 
x = Concatenate(axis=3)([x, b_3])

x = incp_v3(x, 32)

x = UpSampling2D((2, 2))(x) 
x = Concatenate(axis=3)([x, b_2])

x = incp_v3(x, 16)

x = UpSampling2D((2, 2))(x) 
x = Concatenate(axis=3)([x, b_1])

x = incp_v3(x, 8)

x = UpSampling2D((2, 2))(x) 
x = Concatenate(axis=3)([x, b_0])

decoded = Conv2D(1, (3,3), activation='sigmoid', padding='same', kernel_initializer='glorot_normal')(x)

model = Model(inp, decoded)
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=['accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 8)  32          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512, 512, 8)  32          conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 8)  584         leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 8)  32          input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512, 512, 8)  32          conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 512, 512, 8)  32          conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 512, 512, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 512, 512, 8)  584         leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 8)  584         leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 512, 8)  32          input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 512, 512, 8)  32          max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 512, 512, 8)  32          conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 512, 512, 8)  32          conv2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 512, 512, 8)  32          conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 512, 512, 8)  32          conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 512, 512, 8)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512, 512, 32) 0           leaky_re_lu_3[0][0]
#                                                                  leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_6[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 256, 256, 32) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 16) 528         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 16) 64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 256, 256, 16) 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 16) 2320        leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 16) 528         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256, 256, 16) 64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 256, 16) 64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 256, 256, 16) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 256, 256, 32) 0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 256, 256, 16) 2320        leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 16) 2320        leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 16) 528         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 16) 528         max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 256, 256, 16) 64          conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 256, 256, 16) 64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 256, 256, 16) 64          conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 16) 64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 256, 16) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 64) 0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
#                                                                  leaky_re_lu_13[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64) 0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 32) 2080        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 128, 128, 32) 128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 32) 9248        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 32) 2080        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 32) 128         conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 128, 128, 32) 128         conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 64) 0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 32) 9248        leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 32) 9248        leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 32) 2080        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 32) 2080        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 32) 128         conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 128, 128, 32) 128         conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 128, 128, 32) 128         conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 128, 128, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, 128, 128, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 128 0           leaky_re_lu_17[0][0]
#                                                                  leaky_re_lu_19[0][0]
#                                                                  leaky_re_lu_20[0][0]
#                                                                  leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 128)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 64, 64, 64)   8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 64, 64, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 64)   36928       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 64, 64, 64)   256         conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 64, 64, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 64, 64, 128)  0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   36928       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 64)   36928       leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 64)   8256        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 64, 64, 64)   8256        max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 64, 64, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 64, 64, 64)   256         conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 64, 64, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 64, 64, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 64, 64, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 64, 64, 256)  0           leaky_re_lu_24[0][0]
#                                                                  leaky_re_lu_26[0][0]
#                                                                  leaky_re_lu_27[0][0]
#                                                                  leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 32, 32, 256)  0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 64)   16448       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 64)   256         conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 64)   16448       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 64)   256         conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 32, 32, 256)  0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 64)   16448       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 64)   16448       max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 64)   256         conv2d_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 32, 32, 64)   256         conv2d_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 32, 32, 64)   256         conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 32, 32, 64)   0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 256)  0           leaky_re_lu_31[0][0]
#                                                                  leaky_re_lu_33[0][0]
#                                                                  leaky_re_lu_34[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 384)  0           up_sampling2d_1[0][0]
#                                                                  max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 32)   12320       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 64, 64, 32)   128         conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 64, 64, 32)   12320       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 64, 64, 32)   128         conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 64, 64, 32)   128         conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 64, 64, 384)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 32)   12320       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 32)   12320       max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 64, 64, 32)   128         conv2d_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 64, 64, 32)   128         conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 64, 64, 32)   128         conv2d_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 64, 64, 32)   128         conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 64, 64, 32)   0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 128)  0           leaky_re_lu_38[0][0]
#                                                                  leaky_re_lu_40[0][0]
#                                                                  leaky_re_lu_41[0][0]
#                                                                  leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 128 0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 192 0           up_sampling2d_2[0][0]
#                                                                  max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 16) 3088        concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 128, 128, 16) 64          conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 128, 128, 16) 3088        concatenate_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 128, 128, 16) 64          conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 128, 128, 16) 64          conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 128, 128, 192 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 128, 128, 16) 3088        concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 128, 128, 16) 3088        max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 128, 128, 16) 64          conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 128, 128, 16) 64          conv2d_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 128, 128, 16) 64          conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 128, 128, 16) 64          conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, 128, 128, 16) 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 128, 128, 64) 0           leaky_re_lu_45[0][0]
#                                                                  leaky_re_lu_47[0][0]
#                                                                  leaky_re_lu_48[0][0]
#                                                                  leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64) 0           concatenate_9[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 256, 256, 96) 0           up_sampling2d_3[0][0]
#                                                                  max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 256, 256, 8)  776         concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 256, 256, 8)  32          conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 256, 256, 8)  584         leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 256, 256, 8)  776         concatenate_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 256, 256, 8)  32          conv2d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 256, 256, 8)  32          conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 256, 256, 96) 0           concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 256, 256, 8)  584         leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 256, 256, 8)  584         leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 256, 256, 8)  776         concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 256, 256, 8)  776         max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 256, 256, 8)  32          conv2d_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 256, 256, 8)  32          conv2d_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 256, 256, 8)  32          conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 256, 256, 8)  32          conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, 256, 256, 8)  0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 256, 256, 32) 0           leaky_re_lu_52[0][0]
#                                                                  leaky_re_lu_54[0][0]
#                                                                  leaky_re_lu_55[0][0]
#                                                                  leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 512, 512, 32) 0           concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 512, 512, 64) 0           up_sampling2d_4[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 512, 512, 1)  577         concatenate_12[0][0]
# ==================================================================================================
# Total params: 475,889
# Trainable params: 472,529
# Non-trainable params: 3,360
# __________________________________________________________________________________________________

# %%
batch_size = 8

# image_augmenting function
def image_augmentation(imgs, masks): 
    data_gen_args = dict(featurewise_center=False,
                         featurewise_std_normalization=False,
                         zoom_range = [0.9, 1.1],
                         width_shift_range=0.1,
                         height_shift_range=0.1,
                         horizontal_flip=True,
                         vertical_flip = True 
                                                ) 
    
    image_datagen = ImageDataGenerator(**data_gen_args)
    mask_datagen = ImageDataGenerator(**data_gen_args)
    seed = 1
    
    image_datagen.fit(imgs, augment=True, seed=seed)
    mask_datagen.fit(masks, augment=True, seed=seed)
    
    image_generator = image_datagen.flow(
        imgs,
        batch_size=batch_size,
        shuffle=True,
        seed=seed)
    
    mask_generator = mask_datagen.flow(
        masks,
        batch_size=batch_size,
        shuffle=True,
        seed=seed)

    train_generator = zip(image_generator, mask_generator)
    
    return train_generator

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=3)
x_train.shape, x_test.shape
# Out:
# ((240, 512, 512, 3), (27, 512, 512, 3))

# %%
train_generator = image_augmentation(x_train, y_train)
test_generator = image_augmentation(x_test, y_test)

# %%
from keras.callbacks import TensorBoard,LearningRateScheduler
tb = TensorBoard(log_dir='./logs/lungs_incp_unet_snapshot', histogram_freq=0, batch_size=batch_size, write_graph=True, write_grads=True, write_images=True,
                 embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None)

# %%
# Model parameters
M = 8
nb_epoch = T = 1600
alpha_zero = 1e-3
snapshot = SnapshotCallbackBuilder(T, M, alpha_zero)
timestr = time.strftime("%Y-%m-%d_%H-%M-%S")
model_prefix = './lungs_incp_unet_snapshot{}'.format(timestr)

# Train model
callbacks = [tb] + snapshot.get_callbacks(model_prefix = model_prefix) 
model.fit_generator(train_generator, steps_per_epoch=30, epochs=nb_epoch, callbacks=callbacks, verbose=0)


## may give location you want to save the model to.
model.save('./lungs_incp_unet_snapshot')

# %%
pred = model.predict(x_test)

# %%
plt.gray()
for i, p in enumerate(pred):
    plt.grid(),plt.subplot(122),plt.imshow(p.reshape(p.shape[0],p.shape[1]))
    plt.title('Detected segment'), plt.xticks([]), plt.yticks([])
    plt.grid(),plt.subplot(121),plt.imshow(x_test[i])
    plt.title('image'), plt.xticks([]), plt.yticks([])
    plt.show()
print(time.localtime())
# Out:
# time.struct_time(tm_year=2019, tm_mon=1, tm_mday=18, tm_hour=18, tm_min=35, tm_sec=43, tm_wday=4, tm_yday=18, tm_isdst=0)

# %%
temp = []
for im in y_test:
    im *=255
    _, im = cv2.threshold(im, 200, 255, cv2.THRESH_BINARY)
    temp.append(im)
y_test_t = np.array(temp)

# %%
temp = []
for im in pred:
    im *=255
    _, im = cv2.threshold(im, 200, 255, cv2.THRESH_BINARY)
    temp.append(im)
pred_t = np.array(temp)

# %% [markdown]
# ## IOU
#
# Intersection Over Union is used to evaluate the models performance.
#
# The predicted image is compared with the corresponding mask of the test image.

# %%
component1 = np.float32(y_test_t)
component2 = pred_t
overlap = np.logical_and(component1, component2) # Logical AND
union = np.logical_or(component1, component2) # Logical OR

IOU = overlap.sum()/float(union.sum())
IOU
# Out:
# 0.9771385524850905
